# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import pathlib
import os 

# %matplotlib inline

# %%
folder = "Selection Tables"
files = [str(file) for file in pathlib.Path(os.path.join(os.getcwd(), folder)).glob("*.txt")]

# %%
# Quick way to extract the columns of a dataframe. 
with open(files[0], "r") as file:
    df = pd.read_csv(file, delimiter = "\t")

columns = [column for column in df.columns]

# %%
df = pd.DataFrame(columns = columns)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Selection, View, Channel, Begin Time (s), End Time (s), Low Freq (Hz), High Freq (Hz), Begin File, Begin Path, Label]
# Index: []

# %%
for file in files:
    with open(file, "r") as f:
        tmp_df = pd.read_csv(f, delimiter = "\t")
        df = pd.concat([df, tmp_df], axis = 0)

# %%
df[df["Label"].isna()]
# Out:
#     Selection           View Channel  Begin Time (s)  End Time (s)  \
# 35         38  Spectrogram 1       1      219.995489    220.803919
# 88         89  Spectrogram 1       1      299.999937    299.999937
# 99        100  Spectrogram 1       1      118.434930    119.692552
# 100       101  Spectrogram 1       1      123.465417    124.799258
# 101       102  Spectrogram 1       1      127.428831    128.419684
# 102       103  Spectrogram 1       1      133.831268    134.822122
# 103       104  Spectrogram 1       1      138.656292    139.990134
# 104       105  Spectrogram 1       1      148.298059    148.945924
# 105       106  Spectrogram 1       1      150.670621    151.585255
# 106       107  Spectrogram 1       1      151.890133    152.766658
# 107       108  Spectrogram 1       1      155.472450    156.501413
# 108       109  Spectrogram 1       1      166.409947    167.248362
# 109       110  Spectrogram 1       1      170.449581    171.402324
# 110       111  Spectrogram 1       1      182.184257    183.060781
# 111       112  Spectrogram 1       1      188.731672    189.913074
# 112       113  Spectrogram 1       1      222.078932    223.069785
# 113       114  Spectrogram 1       1      216.019482    217.200884
# 114       115  Spectrogram 1       1      228.062162    229.091125
# 116       117  Spectrogram 1       1      244.484899    245.437643
# 117       118  Spectrogram 1       1      258.471176    259.500140
# 118       119  Spectrogram 1       1      283.531401    284.598474
# 119       120  Spectrogram 1       1      295.269203    296.450605
# 120       121  Spectrogram 1       1      298.813410    299.689934
# 121       122  Spectrogram 1       1      298.737190    299.423166
# 122       123  Spectrogram 1       1       28.072935     29.292447
# 123       124  Spectrogram 1       1       33.903726     35.161348
# 124       125  Spectrogram 1       1       35.885433     36.876287
#
#      Low Freq (Hz)  High Freq (Hz)           Begin File  \
# 35          1230.6          1578.0  20200929_032722.WAV
# 88           819.6           819.6  20200927_011212.WAV
# 99          1807.5          2460.3  20200929_033000.WAV
# 100         1841.0          2510.5  20200929_033000.WAV
# 101         1907.9          2343.1  20200929_033000.WAV
# 102         1690.4          2309.6  20200929_033000.WAV
# 103         1790.8          2242.7  20200929_033000.WAV
# 104         1991.6          2410.0  20200929_033000.WAV
# 105         1807.5          2209.2  20200929_033000.WAV
# 106         1941.4          2560.7  20200929_033000.WAV
# 107         1824.3          2343.1  20200929_033000.WAV
# 108         1790.8          2276.2  20200929_033000.WAV
# 109         1841.0          2276.2  20200929_033000.WAV
# 110         1790.8          2242.7  20200929_033000.WAV
# 111         1824.3          2343.1  20200929_033000.WAV
# 112         1807.5          2292.9  20200929_033000.WAV
# 113         1740.6          2393.3  20200929_033000.WAV
# 114         1824.3          2292.9  20200929_033000.WAV
# 116         1795.4          2247.3  20200929_033000.WAV
# 117         1695.0          2331.0  20200929_033000.WAV
# 118         3552.8          4188.7  20200929_033000.WAV
# 119         3619.7          4172.0  20200929_033000.WAV
# 120         3603.0          4138.5  20200929_033000.WAV
# 121         2531.8          2967.0  20200929_033000.WAV
# 122         1745.2          2381.2  20200929_033000.WAV
# 123         1678.3          2364.5  20200929_033000.WAV
# 124         1695.0          2398.0  20200929_033000.WAV
#
#                                             Begin Path Label
# 35   D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 88   D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 99   D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 100  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 101  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 102  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 103  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 104  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 105  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 106  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 107  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 108  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 109  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 110  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 111  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 112  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 113  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 114  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 116  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 117  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 118  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 119  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 120  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 121  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 122  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 123  D:\Fauna & Flora International\VietnamAudioSto...   NaN
# 124  D:\Fauna & Flora International\VietnamAudioSto...   NaN
